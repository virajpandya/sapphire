# %%
# easiest to re-read in the config that determined ODE model setup
# this should've been same regardless of inference constraints
from sapphire.utils import read_config
config = read_config.get({'path_config':'/mnt/ceph/users/vpandya/sapphire/scripts/config.yaml'})

from sapphire import visualization

output_dir = '/mnt/ceph/users/vpandya/sapphire_outputs/'

# %%
visualization.numpyro_plots.multicorner(output_dir,'numpyro_mix_chain%s_%s_slope4_mzrgas_samples12K.npz',
                                        config,figname='multicorner_fiducial_samples12K.png')
# Out:
# Parameter A_M in chain SMHM is not constrained
# Parameter A_SF in chain SMHM is not constrained
# Parameter A_Z in chain SMHM+f$_{\rm ISM}$ is not constrained
# Parameter alpha0_Z in chain SMHM is not constrained
# Parameter alpha0_Z in chain SMHM+f$_{\rm ISM}$ is not constrained
# saved /mnt/ceph/users/vpandya/sapphire_outputs/figures/multicorner_fiducial_samples12Kb.png

# %%
visualization.numpyro_plots.corner(output_dir,'numpyro_mix_chain%s_111_slope4.npz',config,figname=False)
visualization.numpyro_plots.corner(output_dir,'numpyro_mix_chain%s_111_slope4_shiftsmhmdown03.npz',config,figname=False)
visualization.numpyro_plots.corner(output_dir,'numpyro_mix_chain%s_111_slope4_shiftsmhmup03.npz',config,figname=False)
# Out:
# Parameter alpha0_Z in chain NUTS chain 3 is not constrained
# Parameter alpha0_M in chain NUTS chain 3 is not constrained
# Parameter A_Z in chain NUTS chain 3 is not constrained
# Parameter alpha0_Z in chain NUTS chain 3 is not constrained
# Parameter A_E in chain NUTS chain 3 is not constrained
# Parameter A_Z in chain NUTS chain 3 is not constrained
# Parameter alpha0_Z in chain NUTS chain 3 is not constrained
