# %%
from sapphire import visualization
# Out:
# /mnt/home/vpandya/miniconda3/envs/japphire/lib/python3.12/site-packages/arviz/__init__.py:39: FutureWarning:
# ArviZ is undergoing a major refactor to improve flexibility and extensibility while maintaining a user-friendly interface.
# Some upcoming changes may be backward incompatible.
# For details and migration guidance, visit: https://python.arviz.org/en/latest/user_guide/migration_guide.html
#   warn(
# /mnt/home/vpandya/miniconda3/envs/japphire/lib/python3.12/site-packages/jax_cosmo/__init__.py:2: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound

# %%
visualization.numpyro_plots.marginals(output_path='/mnt/ceph/users/vpandya/sapphire_outputs/',
        runs=[{'filename':'numpyro_mix_chain%s_111_slope4_mzrgas.npz','color':'gray','label':'__none__',
              'obs_color':'k','obs_label':'fiducial'},
              {'filename':'numpyro_mix_chain%s_111_slope4_mzrgas_shiftsmhmdown.npz','color':'lightcoral','label':'__none__',
              'obs_color':'indianred','obs_label':r'SMHM $-0.3$ dex'},
              {'filename':'numpyro_mix_chain%s_111_slope4_mzrgas_shiftsmhmup.npz','color':'skyblue','label':'__none__',
              'obs_color':'steelblue','obs_label':r'SMHM $+0.3$ dex'}],
          leg_axnum=0,leg_loc='upper left',leg_ncol=1,
                                      figname='marginals_shiftsmhm_111_mzrgas.png')
# Out:
# saved /mnt/ceph/users/vpandya/sapphire_outputs/figures/marginals_shiftsmhm_111_mzrgas.png

# %%
visualization.numpyro_plots.marginals(output_path='/mnt/ceph/users/vpandya/sapphire_outputs/',
        runs=[{'filename':'numpyro_mix_chain%s_111_slope4_mzrgas.npz','color':'gray','label':'__none__',
              'obs_color':'k','obs_label':'fiducial'},
              {'filename':'numpyro_mix_chain%s_111_slope4_mzrgas_shiftfgasdown.npz','color':'lightcoral','label':'__none__',
              'obs_color':'indianred','obs_label':r'$f_{\rm gas}$ $-0.3$ dex'},
              {'filename':'numpyro_mix_chain%s_111_slope4_mzrgas_shiftfgasup.npz','color':'skyblue','label':'__none__',
              'obs_color':'steelblue','obs_label':r'$f_{\rm gas}$ $+0.3$ dex'}],
          leg_axnum=0,leg_loc='upper left',leg_ncol=1,
                                     figname='marginals_shiftfgas_111_mzrgas.png')
# Out:
# saved /mnt/ceph/users/vpandya/sapphire_outputs/figures/marginals_shiftfgas_111_mzrgas.png

# %%
visualization.numpyro_plots.marginals(output_path='/mnt/ceph/users/vpandya/sapphire_outputs/',
        runs=[{'filename':'numpyro_mix_chain%s_111_slope4_mzrgas.npz','color':'gray','label':'__none__',
              'obs_color':'k','obs_label':'fiducial'},
              {'filename':'numpyro_mix_chain%s_111_slope4_mzrgas_shiftmzrdown.npz','color':'lightcoral','label':'__none__',
              'obs_color':'indianred','obs_label':r'MZR $-0.3$ dex'},              
              {'filename':'numpyro_mix_chain%s_111_slope4_mzrgas_shiftmzrup.npz','color':'skyblue','label':'__none__',
              'obs_color':'steelblue','obs_label':r'MZR $+0.3$ dex'}],
          leg_axnum=0,leg_loc='upper left',leg_ncol=1,
          figname='marginals_shiftmzr_111_mzrgas.png')
# Out:
# saved /mnt/ceph/users/vpandya/sapphire_outputs/figures/marginals_shiftmzr_111_mzrgas.png

# %%
visualization.numpyro_plots.marginals(output_path='/mnt/ceph/users/vpandya/sapphire_outputs/',
        runs=[{'filename':'numpyro_mix_chain%s_111_slope4_mzrgas.npz','color':'orange','label':'__none__',
              'obs_color':'k','obs_label':'Behroozi+19'},
              {'filename':'numpyro_mix_chain%s_111_slope4_mzrgas_behroozicutmvir.npz','color':'hotpink','label':'__none__',
              'obs_color':'indianred','obs_label':r'Behroozi+19 $M_{\rm vir}$ cut'},
              {'filename':'numpyro_manga_chain%s_111_slope4_mzrgas_mangasmhm.npz','color':'mediumseagreen','label':'__none__',
              'obs_color':'steelblue','obs_label':r'MaNGA SMHM'}],
          leg_axnum=0,leg_loc='upper left',leg_ncol=1,
                                     figname='marginals_cutsmhm_111_mzrgas_appendixA.png')
# Out:
# saved /mnt/ceph/users/vpandya/sapphire_outputs/figures/marginals_cutsmhm_111_mzrgas_appendixA.png
