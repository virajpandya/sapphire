# %%
from sapphire import visualization

# %%
visualization.numpyro_plots.trace('/mnt/ceph/users/vpandya/sapphire_outputs/',
                                  'numpyro_mix_chain%s_100_slope4_mzrgas.npz',figname=None)

visualization.numpyro_plots.trace('/mnt/ceph/users/vpandya/sapphire_outputs/',
                                  'numpyro_mix_chain%s_110_slope4_mzrgas.npz',figname=None)

visualization.numpyro_plots.trace('/mnt/ceph/users/vpandya/sapphire_outputs/',
                                  'numpyro_mix_chain%s_111_slope4_mzrgas.npz',figname=None)

# %%
visualization.numpyro_plots.trace('/mnt/ceph/users/vpandya/sapphire_outputs/',
                                  'numpyro_mix_chain%s_111_slope4_mzrgas_shiftsmhmup.npz',figname=None)

visualization.numpyro_plots.trace('/mnt/ceph/users/vpandya/sapphire_outputs/',
                                  'numpyro_mix_chain%s_111_slope4_mzrgas_shiftsmhmdown.npz',figname=None)

# %%
visualization.numpyro_plots.trace('/mnt/ceph/users/vpandya/sapphire_outputs/',
                                  'numpyro_mix_chain%s_111_slope4_mzrgas_shiftfgasup.npz',figname=None)

visualization.numpyro_plots.trace('/mnt/ceph/users/vpandya/sapphire_outputs/',
                                  'numpyro_mix_chain%s_111_slope4_mzrgas_shiftfgasdown.npz',figname=None)

# %%
visualization.numpyro_plots.trace('/mnt/ceph/users/vpandya/sapphire_outputs/',
                                  'numpyro_mix_chain%s_111_slope4_mzrgas_shiftmzrup.npz',figname=None)

visualization.numpyro_plots.trace('/mnt/ceph/users/vpandya/sapphire_outputs/',
                                  'numpyro_mix_chain%s_111_slope4_mzrgas_shiftmzrdown.npz',figname=None)

# %%
visualization.numpyro_plots.trace('/mnt/ceph/users/vpandya/sapphire_outputs/',
                                  'numpyro_mix_chain%s_111_slope4_mzrgas.npz',figname=None)

# probably tenth
# visualization.numpyro_plots.trace('/mnt/ceph/users/vpandya/sapphire_outputs/',
#                                   'numpyro_mix_chain%s_111.npz',figname=None)


# visualization.numpyro_plots.trace('/mnt/ceph/users/vpandya/sapphire_outputs/',
#                                   'numpyro_mix_chain%s_111_slope4_mzrgas_scaleerrhalf.npz',figname=None)


# visualization.numpyro_plots.trace('/mnt/ceph/users/vpandya/sapphire_outputs/',
#                                   'numpyro_mix_chain%s_111_slope4_mzrgas_scaleerrtenth.npz',figname=None)

# %%
visualization.numpyro_plots.trace('/mnt/ceph/users/vpandya/sapphire_outputs/',
                                  'numpyro_mix_chain%s_111_slope4_mzrgas.npz',figname=None)

visualization.numpyro_plots.trace('/mnt/ceph/users/vpandya/sapphire_outputs/',
                                  'numpyro_mix_chain%s_111_slope4_mzrgas_behroozicutmvir.npz',figname=None)

visualization.numpyro_plots.trace('/mnt/ceph/users/vpandya/sapphire_outputs/',
                                  'numpyro_manga_chain%s_111_slope4_mzrgas_mangasmhm.npz',figname=None)
