# %%
from sapphire import visualization

# %%
visualization.numpyro_plots.trace('/mnt/ceph/users/vpandya/sapphire_outputs/',
                                  'numpyro_mix_chain%s_111.npz',savefig=False)

visualization.numpyro_plots.trace('/mnt/ceph/users/vpandya/sapphire_outputs/',
                                  'numpyro_mix_chain%s_110.npz',savefig=False)

visualization.numpyro_plots.trace('/mnt/ceph/users/vpandya/sapphire_outputs/',
                                  'numpyro_mix_chain%s_100.npz',savefig=False)
