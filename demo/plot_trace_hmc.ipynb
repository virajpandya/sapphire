# %%
from sapphire import visualization

# %%
visualization.numpyro_plots.trace('/mnt/ceph/users/vpandya/sapphire_outputs/',
                                  'numpyro_manga_chain%s_111_fixsmhm.npz',savefig=False)

visualization.numpyro_plots.trace('/mnt/ceph/users/vpandya/sapphire_outputs/',
                                  'numpyro_manga_chain%s_110_fixsmhm.npz',savefig=False)

visualization.numpyro_plots.trace('/mnt/ceph/users/vpandya/sapphire_outputs/',
                                  'numpyro_manga_chain%s_100_fixsmhm.npz',savefig=False)
